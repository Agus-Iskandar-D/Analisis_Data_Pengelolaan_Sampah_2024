# %% [markdown]
# # Query 1: Mengecek Capaian Pengurangan Sampah
# ### Tujuan: Mengecek apakah pengurangan sampah memenuhi target pengurangan sampah sebesar 30%
# ### Konsep: If-else, Pandas untuk CSV
# ### Output: Status capaian pengurangan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

target_pengurangan = 30

for index, row in df.iterrows():
    pengurangan = row['%Pengurangan Sampah(B/A)']
    kabupaten = row['Kabupaten/Kota']
    if pengurangan > target_pengurangan:
        print(f"{kabupaten} memenuhi target pengurangan sebesar {pengurangan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target pengurangan sebesar {pengurangan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target pengurangan sebesar 0.02 %
# Kab. Aceh Tenggara BELUM memenuhi target pengurangan sebesar 0.05 %
# Kab. Aceh Timur BELUM memenuhi target pengurangan sebesar 1.61 %
# Kab. Aceh Tengah BELUM memenuhi target pengurangan sebesar 2.65 %
# Kab. Aceh Barat BELUM memenuhi target pengurangan sebesar 4.11 %
# Kab. Aceh Besar BELUM memenuhi target pengurangan sebesar 2.43 %
# Kab. Pidie BELUM memenuhi target pengurangan sebesar nan %
# Kab. Aceh Utara BELUM memenuhi target pengurangan sebesar 1.09 %
# Kab. Simeulue BELUM memenuhi target pengurangan sebesar 4.6 %
# Kab. Aceh Singkil BELUM memenuhi target pengurangan sebesar 3.98 %
# Kab. Bireuen BELUM memenuhi target pengurangan sebesar 17.13 %
# Kab. Aceh Barat Daya BELUM memenuhi target pengurangan sebesar 7.33 %
# Kab. Gayo Lues BELUM memenuhi target pengurangan sebesar 2.99 %
# Kab. Aceh Jaya BELUM memenuhi target pengurangan sebesar 1.76 %
# ...

# %% [markdown]
# # Query 2: Mengecek Capaian Penanganan Sampah
# ### Tujuan: Mengecek apakah capaian target penanganan sampah sebesar 70%
# ### Konsep if-else, Pandas untuk baca csv
# ### Output: Status capaian penanganan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

target_penanganan = 70

for index, row in df.iterrows():
    penanganan = row['%Penanganan Sampah(C/A)']
    kabupaten = row['Kabupaten/Kota']
    if penanganan > target_penanganan:
        print(f"{kabupaten} memenuhi target penanganan sebesar {penanganan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target penanganan sebesar {penanganan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target penanganan sebesar 37.0 %
# Kab. Aceh Tenggara BELUM memenuhi target penanganan sebesar 15.4 %
# Kab. Aceh Timur BELUM memenuhi target penanganan sebesar 42.89 %
# Kab. Aceh Tengah BELUM memenuhi target penanganan sebesar 55.71 %
# Kab. Aceh Barat memenuhi target penanganan sebesar 75.91 %
# Kab. Aceh Besar BELUM memenuhi target penanganan sebesar 66.72 %
# Kab. Pidie BELUM memenuhi target penanganan sebesar 22.6 %
# Kab. Aceh Utara BELUM memenuhi target penanganan sebesar 16.11 %
# Kab. Simeulue BELUM memenuhi target penanganan sebesar 39.45 %
# Kab. Aceh Singkil BELUM memenuhi target penanganan sebesar 12.75 %
# Kab. Bireuen BELUM memenuhi target penanganan sebesar 46.77 %
# Kab. Aceh Barat Daya BELUM memenuhi target penanganan sebesar 23.74 %
# Kab. Gayo Lues memenuhi target penanganan sebesar 71.53 %
# Kab. Aceh Jaya BELUM memenuhi target penanganan sebesar 63.35 %
# Kab. Nagan Raya BELUM memenuhi target penanganan sebesar 50.24 %
# ...

# %% [markdown]
# # Query 3: Mengecek Capaian Pengalolaan Sampah
# ### Tujuan: Mengecek apakah capaian target pengeloaan dengan asumsi 70% (sama dengan target penangan)
# ### Konsep if-else, Pandas untuk baca csv
# ### Output: Status capaian pengeloaan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

target_pengelolaan = 70

for index, row in df.iterrows():
    pengelolaan = row['%Sampah Terkelola(B+C)/A']
    kabupaten = row['Kabupaten/Kota']
    if pengelolaan > target_pengelolaan:
        print(f"{kabupaten} memenuhi target penanganan sebesar {pengelolaan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target penanganan sebesar {pengelolaan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target penanganan sebesar 37.02 %
# Kab. Aceh Tenggara BELUM memenuhi target penanganan sebesar 15.45 %
# Kab. Aceh Timur BELUM memenuhi target penanganan sebesar 44.5 %
# Kab. Aceh Tengah BELUM memenuhi target penanganan sebesar 58.37 %
# Kab. Aceh Barat memenuhi target penanganan sebesar 80.02 %
# Kab. Aceh Besar BELUM memenuhi target penanganan sebesar 69.15 %
# Kab. Pidie BELUM memenuhi target penanganan sebesar 22.6 %
# Kab. Aceh Utara BELUM memenuhi target penanganan sebesar 17.2 %
# Kab. Simeulue BELUM memenuhi target penanganan sebesar 44.05 %
# Kab. Aceh Singkil BELUM memenuhi target penanganan sebesar 16.73 %
# Kab. Bireuen BELUM memenuhi target penanganan sebesar 63.9 %
# Kab. Aceh Barat Daya BELUM memenuhi target penanganan sebesar 31.07 %
# Kab. Gayo Lues memenuhi target penanganan sebesar 74.52 %
# Kab. Aceh Jaya BELUM memenuhi target penanganan sebesar 65.11 %
# Kab. Nagan Raya BELUM memenuhi target penanganan sebesar 67.62 %
# ...

# %% [markdown]
# # Query 4: Menyimpan Data Capaian Pengurangan Sampah dalam List
# ### Tujuan: Menyimpan capaian pengurangan dari CSV ke dalam List untuk Analisis
# ### Konsep: List dan for loop, Pandas untuk Baca CSV
# ### Output: List Berisi capaian pengurangan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengurangan_list = []

for index, row in df.iterrows():

   pengurangan = row['%Pengurangan Sampah(B/A)']
   pengurangan_list.append(pengurangan)

print("Capaian Pengurangan Sampah:", pengurangan_list)
# Out:
# Capaian Pengurangan Sampah: [0.02, 0.05, 1.61, 2.65, 4.11, 2.43, nan, 1.09, 4.6, 3.98, 17.13, 7.33, 2.99, 1.76, 17.39, 4.38, 0.08, 0.0, 16.37, 0.0, 1.1, 9.13, 0.51, 0.02, 0.65, 0.3, 0.0, 0.7, 15.1, 18.57, 13.38, 20.44, 1.4, 14.73, 18.57, 14.21, 21.91, 11.17, 26.18, 16.64, 13.29, 15.39, 10.77, 10.23, 6.98, 14.45, 14.72, 3.24, 11.58, 2.4, 12.51, 9.03, 22.49, 22.55, 9.17, 23.64, 2.53, 0.02, 2.44, 0.35, 0.42, 21.06, 8.68, nan, 3.46, 1.48, 8.94, 0.09, 1.73, 3.2, 0.04, 4.35, 5.59, 11.88, 0.0, 6.2, 18.08, 4.24, 0.13, 9.96, 12.56, 6.21, 21.97, 28.02, 28.03, 28.03, 28.06, 28.01, 28.18, 2.93, 0.39, 33.41, 12.56, 0.04, 39.81, 2.59, 0.35, 12.39, 1.68, 0.75, 0.41, 24.35, 18.0, 10.88, 22.57, 16.2, 64.14, 0.22, 15.27, 27.42, 23.24, 16.21, 11.1, 14.52, 14.67, 24.71, 12.5, 0.07, 9.55, 0.7, 1.7, 16.29, 19.21, 20.75, 27.67, 31.07, 18.4, 24.28, 13.88, 21.96, 17.22, 13.94, 11.7, 3.03, 0.79, 30.23, 0.52, 9.51, 5.31, 28.13, 14.77, 27.46, 53.79, 16.12, 23.63, 14.58, 14.36, 15.43, 15.69, 27.0, 16.86, 20.19, 
# ...

# %% [markdown]
# # Query 5: Menyimpan Data Capaian Penanganan Sampah dalam List
# ### Tujuan: Menyimpan capaian penanganan dari CSV ke dalam List untuk Analisis
# ### Konsep: List dan for loop, Pandas untuk Baca CSV
# ### Output: List Berisi capaian pengurangan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

penanganan_list = []

for index, row in df.iterrows():

   penanganan = row['%Penanganan Sampah(C/A)']
   penanganan_list.append(penanganan)

print("Capaian Penanganan Sampah:", penanganan_list)
# Out:
# Capaian Penanganan Sampah: [37.0, 15.4, 42.89, 55.71, 75.91, 66.72, 22.6, 16.11, 39.45, 12.75, 46.77, 23.74, 71.53, 63.35, 50.24, 20.85, 62.47, 19.37, 80.77, 73.29, 76.98, 71.62, 71.6, nan, 16.74, 26.07, 20.12, 42.05, 80.12, 23.36, 14.39, 35.99, 22.71, 31.55, 6.23, 15.57, 74.64, 88.43, 73.02, 82.66, 80.28, 79.3, 75.24, 67.9, 22.13, 42.84, 24.92, 63.24, 68.11, 21.93, 73.95, 70.79, 37.5, 35.08, 28.79, 20.34, 45.55, 37.14, 35.25, 62.98, 60.33, 64.43, 8.1, 4.88, 26.28, 16.75, 85.76, 39.24, 6.85, 7.76, 0.55, 9.03, 21.51, 27.19, 8.72, 52.5, 56.97, 21.27, 45.25, 71.83, 45.44, 4.6, 63.75, 71.61, 71.54, 71.71, 71.8, 71.96, 71.59, 27.98, 25.97, 29.42, 21.29, 7.16, 42.36, 38.45, 14.25, 50.19, 16.51, 35.97, 53.82, 69.04, 67.59, 73.46, 73.29, 69.68, 33.86, 13.1, 35.73, 35.61, 35.59, 63.76, 36.5, 23.86, 27.81, 42.73, 41.67, 63.94, 45.09, 45.82, 18.96, 78.39, 79.24, 77.52, 71.34, 14.17, 13.04, 15.69, 10.17, 60.42, 12.36, 33.39, 16.89, 56.98, 35.23, 27.72, 21.64, 60.67, 58.82, 22.28, 29.04, 16.16, 1
# ...

# %% [markdown]
# # Query 6: Menyimpan Data Capaian Pengelolaan Sampah dalam List
# ### Tujuan: Menyimpan capaian pengelolaan dari CSV ke dalam List untuk Analisis
# ### Konsep: List dan for loop, Pandas untuk Baca CSV
# ### Output: List Berisi capaian pengelolaan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengelolaan_list = []

for index, row in df.iterrows():

   pengelolaan = row ['%Sampah Terkelola(B+C)/A']
   pengelolaan_list.append(pengelolaan)

print("Capaian Pengelolaan Sampah:", pengelolaan_list)
# Out:
# Capaian Pengelolaan Sampah: [37.02, 15.45, 44.5, 58.37, 80.02, 69.15, 22.6, 17.2, 44.05, 16.73, 63.9, 31.07, 74.52, 65.11, 67.62, 25.23, 62.55, 19.37, 97.15, 73.29, 78.08, 80.75, 72.11, 0.02, 17.39, 26.37, 20.12, 42.75, 95.22, 41.93, 27.77, 56.43, 24.11, 46.29, 24.8, 29.78, 96.55, 99.6, 99.2, 99.3, 93.57, 94.69, 86.01, 78.13, 29.11, 57.3, 39.64, 66.49, 79.7, 24.33, 86.45, 79.82, 59.99, 57.63, 37.96, 43.98, 48.08, 37.16, 37.69, 63.33, 60.75, 85.49, 16.79, 4.88, 29.74, 18.24, 94.7, 39.33, 8.58, 10.96, 0.59, 13.38, 27.09, 39.07, 8.73, 58.7, 75.05, 25.51, 45.38, 81.79, 58.0, 10.82, 85.72, 99.64, 99.57, 99.74, 99.86, 99.98, 99.78, 30.91, 26.35, 62.83, 33.85, 7.2, 82.17, 41.04, 14.59, 62.58, 18.18, 36.71, 54.23, 93.39, 85.59, 84.34, 95.85, 85.88, 98.0, 13.32, 51.0, 63.04, 58.83, 79.97, 47.6, 38.38, 42.47, 67.45, 54.17, 64.01, 54.64, 46.52, 20.66, 94.67, 98.45, 98.27, 99.01, 45.24, 31.44, 39.97, 24.04, 82.38, 29.59, 47.34, 28.59, 60.01, 36.02, 57.95, 22.16, 70.18, 64.13, 50.41, 43.81, 43.62
# ...

# %% [markdown]
# # Query 7: Analisis Capaian Pengurangan Sampah dengan Metode List
# ### Tujuan: Mengecek capaian pengurangan sampah
# ### Konsep: List, for Loof, if-else, Pandas untuk Baca CSV
# ### Output: Capaian pengurangan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengurangan_list = []

for index, row in df.iterrows():
   pengurangan = row['%Pengurangan Sampah(B/A)']
   pengurangan_list.append(pengurangan)

target_pengurangan = 30

for i, pengurangan in enumerate(pengurangan_list):
    kabupaten = df.iloc[i]['Kabupaten/Kota']
    if pengurangan > target_pengurangan:
        print(f"{kabupaten} memenuhi target pengurangan sebesar {pengurangan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target pengurangan sebesar {pengurangan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target pengurangan sebesar 0.02 %
# Kab. Aceh Tenggara BELUM memenuhi target pengurangan sebesar 0.05 %
# Kab. Aceh Timur BELUM memenuhi target pengurangan sebesar 1.61 %
# Kab. Aceh Tengah BELUM memenuhi target pengurangan sebesar 2.65 %
# Kab. Aceh Barat BELUM memenuhi target pengurangan sebesar 4.11 %
# Kab. Aceh Besar BELUM memenuhi target pengurangan sebesar 2.43 %
# Kab. Pidie BELUM memenuhi target pengurangan sebesar nan %
# Kab. Aceh Utara BELUM memenuhi target pengurangan sebesar 1.09 %
# Kab. Simeulue BELUM memenuhi target pengurangan sebesar 4.6 %
# Kab. Aceh Singkil BELUM memenuhi target pengurangan sebesar 3.98 %
# Kab. Bireuen BELUM memenuhi target pengurangan sebesar 17.13 %
# Kab. Aceh Barat Daya BELUM memenuhi target pengurangan sebesar 7.33 %
# Kab. Gayo Lues BELUM memenuhi target pengurangan sebesar 2.99 %
# Kab. Aceh Jaya BELUM memenuhi target pengurangan sebesar 1.76 %
# ...

# %% [markdown]
# # Query 8: Analisis Capaian Penanganan Sampah dengan Metode List
# ### Tujuan: Mengecek capaian penanganan sampah
# ### Konsep: List, for Loof, if-else, Pandas untuk Baca CSV
# ### Output: Capaian penanganan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

penanganan_list = []

for index, row in df.iterrows():
   penanganan = row['%Penanganan Sampah(C/A)']
   penanganan_list.append(penanganan)

target_penanganan = 70

for i, penanganan in enumerate(penanganan_list):
    kabupaten = df.iloc[i]['Kabupaten/Kota']
    if penanganan > target_penanganan:
        print(f"{kabupaten} memenuhi target pengurangan sebesar {penanganan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target pengurangan sebesar {penanganan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target pengurangan sebesar 37.0 %
# Kab. Aceh Tenggara BELUM memenuhi target pengurangan sebesar 15.4 %
# Kab. Aceh Timur BELUM memenuhi target pengurangan sebesar 42.89 %
# Kab. Aceh Tengah BELUM memenuhi target pengurangan sebesar 55.71 %
# Kab. Aceh Barat memenuhi target pengurangan sebesar 75.91 %
# Kab. Aceh Besar BELUM memenuhi target pengurangan sebesar 66.72 %
# Kab. Pidie BELUM memenuhi target pengurangan sebesar 22.6 %
# Kab. Aceh Utara BELUM memenuhi target pengurangan sebesar 16.11 %
# Kab. Simeulue BELUM memenuhi target pengurangan sebesar 39.45 %
# Kab. Aceh Singkil BELUM memenuhi target pengurangan sebesar 12.75 %
# Kab. Bireuen BELUM memenuhi target pengurangan sebesar 46.77 %
# Kab. Aceh Barat Daya BELUM memenuhi target pengurangan sebesar 23.74 %
# Kab. Gayo Lues memenuhi target pengurangan sebesar 71.53 %
# Kab. Aceh Jaya BELUM memenuhi target pengurangan sebesar 63.35 %
# ...

# %% [markdown]
# # Query 9: Analisis Capaian Pengelolaan Sampah dengan Metode List
# ### Tujuan: Mengecek capaian pengelolaan sampah
# ### Konsep: List, for Loof, if-else, Pandas untuk Baca CSV
# ### Output: Capaian pengelolaan sampah

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengelolaan_list = []

for index, row in df.iterrows():
   pengelolaan = row['%Sampah Terkelola(B+C)/A']
   pengelolaan_list.append(pengelolaan)

target_pengelolaan = 70

for i, pengelolaan in enumerate(pengelolaan_list):
    kabupaten = df.iloc[i]['Kabupaten/Kota']
    if pengelolaan > target_pengelolaan:
        print(f"{kabupaten} memenuhi target pengurangan sebesar {pengelolaan} %")
    else:
        print(f"{kabupaten} BELUM memenuhi target pengurangan sebesar {pengelolaan} %")
# Out:
# Kab. Aceh Selatan BELUM memenuhi target pengurangan sebesar 37.02 %
# Kab. Aceh Tenggara BELUM memenuhi target pengurangan sebesar 15.45 %
# Kab. Aceh Timur BELUM memenuhi target pengurangan sebesar 44.5 %
# Kab. Aceh Tengah BELUM memenuhi target pengurangan sebesar 58.37 %
# Kab. Aceh Barat memenuhi target pengurangan sebesar 80.02 %
# Kab. Aceh Besar BELUM memenuhi target pengurangan sebesar 69.15 %
# Kab. Pidie BELUM memenuhi target pengurangan sebesar 22.6 %
# Kab. Aceh Utara BELUM memenuhi target pengurangan sebesar 17.2 %
# Kab. Simeulue BELUM memenuhi target pengurangan sebesar 44.05 %
# Kab. Aceh Singkil BELUM memenuhi target pengurangan sebesar 16.73 %
# Kab. Bireuen BELUM memenuhi target pengurangan sebesar 63.9 %
# Kab. Aceh Barat Daya BELUM memenuhi target pengurangan sebesar 31.07 %
# Kab. Gayo Lues memenuhi target pengurangan sebesar 74.52 %
# Kab. Aceh Jaya BELUM memenuhi target pengurangan sebesar 65.11 %
# ...

# %% [markdown]
# # Query 10: Simpan Data Capaian Pengurangan Sampah dalam Dictionary
# ### Tujuan: Menyimpan data capaian pengurangan dari CSV ke dictionary dengan nama sebagai kunci.
# ### Konsep: Dictionary, Pandas untuk baca CSV.
# ### Output: Dictionary berisi pengurangan sampah.

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengurangan_dict = {}

for index, row in df.iterrows():

    kabupaten = row['Kabupaten/Kota']

    pengurangan = row['%Pengurangan Sampah(B/A)']

    pengurangan_dict[kabupaten] = pengurangan

print("Data capaian pengurangan sampah: ", pengurangan_dict)
# Out:
# Data capaian pengurangan sampah:  {'Kab. Aceh Selatan': 0.02, 'Kab. Aceh Tenggara': 0.05, 'Kab. Aceh Timur': 1.61, 'Kab. Aceh Tengah': 2.65, 'Kab. Aceh Barat': 4.11, 'Kab. Aceh Besar': 2.43, 'Kab. Pidie': nan, 'Kab. Aceh Utara': 1.09, 'Kab. Simeulue': 4.6, 'Kab. Aceh Singkil': 3.98, 'Kab. Bireuen': 17.13, 'Kab. Aceh Barat Daya': 7.33, 'Kab. Gayo Lues': 2.99, 'Kab. Aceh Jaya': 1.76, 'Kab. Nagan Raya': 17.39, 'Kab. Aceh Tamiang': 4.38, 'Kab. Bener Meriah': 0.08, 'Kab. Pidie Jaya': 0.0, 'Kota Banda Aceh': 16.37, 'Kota Sabang': 0.0, 'Kota Lhokseumawe': 1.1, 'Kota Langsa': 9.13, 'Kota Subulussalam': 0.51, 'Kab. Nias': 0.02, 'Kab. Langkat': 0.65, 'Kab. Simalungun': 0.3, 'Kab. Dairi': 0.0, 'Kab. Pakpak Bharat': 0.7, 'Kota Medan': 15.1, 'Kab. Pesisir Selatan': 18.57, 'Kab. Solok': 13.38, 'Kab. Tanah Datar': 20.44, 'Kab. Padang Pariaman': 1.4, 'Kab. Agam': 14.73, 'Kab. Lima Puluh Kota': 18.57, 'Kab. Solok Selatan': 14.21, 'Kota Padang': 21.91, 'Kota Solok': 11.17, 'Kota Sawahlunto': 26.18, 'K
# ...

# %% [markdown]
# # Query 11: Simpan Data Capaian Penanganan Sampah dalam Dictionary
# ### Tujuan: Menyimpan data capaian penanganan dari CSV ke dictionary dengan nama sebagai kunci.
# ### Konsep: Dictionary, Pandas untuk baca CSV.
# ### Output: Dictionary berisi penanganan perusahaan.

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

penanganan_dict = {}

for index, row in df.iterrows():

    kabupaten = row['Kabupaten/Kota']

    penanganan = row['%Penanganan Sampah(C/A)']

    penanganan_dict[kabupaten] = penanganan

print("Data capaian penanganan sampah: ", penanganan_dict)
# Out:
# Data capaian penanganan sampah:  {'Kab. Aceh Selatan': 37.0, 'Kab. Aceh Tenggara': 15.4, 'Kab. Aceh Timur': 42.89, 'Kab. Aceh Tengah': 55.71, 'Kab. Aceh Barat': 75.91, 'Kab. Aceh Besar': 66.72, 'Kab. Pidie': 22.6, 'Kab. Aceh Utara': 16.11, 'Kab. Simeulue': 39.45, 'Kab. Aceh Singkil': 12.75, 'Kab. Bireuen': 46.77, 'Kab. Aceh Barat Daya': 23.74, 'Kab. Gayo Lues': 71.53, 'Kab. Aceh Jaya': 63.35, 'Kab. Nagan Raya': 50.24, 'Kab. Aceh Tamiang': 20.85, 'Kab. Bener Meriah': 62.47, 'Kab. Pidie Jaya': 19.37, 'Kota Banda Aceh': 80.77, 'Kota Sabang': 73.29, 'Kota Lhokseumawe': 76.98, 'Kota Langsa': 71.62, 'Kota Subulussalam': 71.6, 'Kab. Nias': nan, 'Kab. Langkat': 16.74, 'Kab. Simalungun': 26.07, 'Kab. Dairi': 20.12, 'Kab. Pakpak Bharat': 42.05, 'Kota Medan': 80.12, 'Kab. Pesisir Selatan': 23.36, 'Kab. Solok': 14.39, 'Kab. Tanah Datar': 35.99, 'Kab. Padang Pariaman': 22.71, 'Kab. Agam': 31.55, 'Kab. Lima Puluh Kota': 6.23, 'Kab. Solok Selatan': 15.57, 'Kota Padang': 74.64, 'Kota Solok': 88.43, 
# ...

# %% [markdown]
# # Query 12: Simpan Data Capaian Pengelolaan Sampah dalam Dictionary
# ### Tujuan: Menyimpan data capaian pengelolaan dari CSV ke dictionary dengan nama sebagai kunci.
# ### Konsep: Dictionary, Pandas untuk baca CSV.
# ### Output: Dictionary berisi pengelolaan sampah.

# %%
import pandas as pd

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')

pengelolaan_dict = {}

for index, row in df.iterrows():

    kabupaten = row['Kabupaten/Kota']

    pengelolaan = row['%Sampah Terkelola(B+C)/A']

    pengelolaan_dict[kabupaten] = pengelolaan

print("Data capaian pengelolaan sampah: ", pengelolaan_dict)
# Out:
# Data capaian pengelolaan sampah:  {'Kab. Aceh Selatan': 37.02, 'Kab. Aceh Tenggara': 15.45, 'Kab. Aceh Timur': 44.5, 'Kab. Aceh Tengah': 58.37, 'Kab. Aceh Barat': 80.02, 'Kab. Aceh Besar': 69.15, 'Kab. Pidie': 22.6, 'Kab. Aceh Utara': 17.2, 'Kab. Simeulue': 44.05, 'Kab. Aceh Singkil': 16.73, 'Kab. Bireuen': 63.9, 'Kab. Aceh Barat Daya': 31.07, 'Kab. Gayo Lues': 74.52, 'Kab. Aceh Jaya': 65.11, 'Kab. Nagan Raya': 67.62, 'Kab. Aceh Tamiang': 25.23, 'Kab. Bener Meriah': 62.55, 'Kab. Pidie Jaya': 19.37, 'Kota Banda Aceh': 97.15, 'Kota Sabang': 73.29, 'Kota Lhokseumawe': 78.08, 'Kota Langsa': 80.75, 'Kota Subulussalam': 72.11, 'Kab. Nias': 0.02, 'Kab. Langkat': 17.39, 'Kab. Simalungun': 26.37, 'Kab. Dairi': 20.12, 'Kab. Pakpak Bharat': 42.75, 'Kota Medan': 95.22, 'Kab. Pesisir Selatan': 41.93, 'Kab. Solok': 27.77, 'Kab. Tanah Datar': 56.43, 'Kab. Padang Pariaman': 24.11, 'Kab. Agam': 46.29, 'Kab. Lima Puluh Kota': 24.8, 'Kab. Solok Selatan': 29.78, 'Kota Padang': 96.55, 'Kota Solok': 99.6,
# ...

# %% [markdown]
# # QUERY 13: Bar Chart Capaian Pengurangan Sampah
# ### Tujuan: Menvisualisasikan pengurangan sampah dalam Bar Chart
# ### Konsep: Metplotlib, dictionary, Pandas untuk Baca CSV
# ### Output: Bar Chart pengurangan sampah dengan target pengurangan

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_pengurangan (pengurangan_dict):
    kabupaten = list(pengurangan_dict.keys())
    pengurangan = [data['pengurangan'] for data in pengurangan_dict.values()]
    plt.bar(kabupaten, pengurangan, color = 'green')
    plt.xlabel('Kabupaten/Kota')
    plt.ylabel('Capaian Pengurangan Sampah (%)')
    plt.title('Capaian Pengurangan Sampah 2024')
    plt.axhline(y=30, color = 'red', linestyle = '--', label = 'Target Pengurangan Sampah (30%)')
    plt.legend()
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')
pengurangan_dict = {}
for index, row in df.iterrows():
    kabupaten = row['Kabupaten/Kota']
    pengurangan_dict[kabupaten] = {'pengurangan': row['%Pengurangan Sampah(B/A)']}

plot_pengurangan(pengurangan_dict)

# %% [markdown]
# # QUERY 13: Bar Chart Capaian Penanganan Sampah
# ### Tujuan: Menvisualisasikan penanganan sampah dalam Bar Chart
# ### Konsep: Metplotlib, dictionary, Pandas untuk Baca CSV
# ### Output: Bar Chart penanganan sampah dengan target penanganan

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_penanganan (penanganan_dict):
    kabupaten = list(penanganan_dict.keys())
    penanganan = [data['penanganan'] for data in penanganan_dict.values()]
    plt.bar(kabupaten, penanganan, color = 'yellow')
    plt.xlabel('Kabupaten/Kota')
    plt.ylabel('Capaian Penanganan Sampah (%)')
    plt.title('Capaian Penanganan Sampah 2024')
    plt.axhline(y=70, color = 'red', linestyle = '--', label = 'Target Penganganan Sampah (70%)')
    plt.legend()
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')
penanganan_dict = {}
for index, row in df.iterrows():
    kabupaten = row['Kabupaten/Kota']
    penanganan_dict[kabupaten] = {'penanganan': row['%Penanganan Sampah(C/A)']}

plot_penanganan(penanganan_dict)

# %% [markdown]
# # QUERY 14: Bar Chart Capaian Pengelolaan Sampah
# ### Tujuan: Menvisualisasikan pengelolaan sampah dalam Bar Chart
# ### Konsep: Metplotlib, dictionary, Pandas untuk Baca CSV
# ### Output: Bar Chart pengelolaan sampah dengan target pengelolaan

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_pengelolaan (pengelolaan_dict):
    kabupaten = list(pengelolaan_dict.keys())
    pengelolaan = [data['pengelolaan'] for data in pengelolaan_dict.values()]
    plt.bar(kabupaten, pengelolaan, color = 'blue')
    plt.xlabel('Kabupaten/Kota')
    plt.ylabel('Capaian Pengelolaan Sampah (%)')
    plt.title('Capaian Pengelolaan Sampah 2024')
    plt.axhline(y=70, color = 'red', linestyle = '--', label = 'Target Pengelolaan Sampah (%)')
    plt.legend()
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

df = pd.read_csv('C:/EnergiHijau2025/Data_Capaian_Pengelolaan_Sampah.csv')
pengelolaan_dict = {}
for index, row in df.iterrows():
    kabupaten = row['Kabupaten/Kota']
    pengelolaan_dict[kabupaten] = {'pengelolaan': row['%Sampah Terkelola(B+C)/A']}

plot_pengelolaan(pengelolaan_dict)

# %% [markdown]
# # QUERY 15: Pie Chart Komposisi Jenis Sampah
# ### Tujuan: Menvisualisasikan Proporsi jenis sampah dari CSV
# ### Konsep: Matplotlib, Dictionary, Pandas untuk Baca CSV
# ### Output: Pie Chart proporsi jenis sampah

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_jenis(data_df):
    
   
    Sisa_Makanan = data_df['Sisa Makanan (%)'].mean()
    Kayu_Ranting = data_df['Kayu-Ranting (%)'].mean()
    Kertas_Karton = data_df['Kertas-Karton (%)'].mean() 
    Plastik = data_df['Plastik(%)'].mean()
    Logam = data_df['Logam(%)'].mean()
    Kain = data_df['Kain(%)'].mean()
    Karet_Kulit = data_df['Karet- Kulit (%)'].mean()
    Kaca = data_df['Kaca(%)'].mean()
    Lainnya = data_df['Lainnya(%)'].mean()

    labels = [
        'Sisa Makanan', 'Kayu Ranting', 'Kertas Karton', 'Plastik',
        'Logam', 'Kain', 'Karet Kulit', 'Kaca', 'Lainnya'
    ]
    sizes = [
        Sisa_Makanan, Kayu_Ranting, Kertas_Karton, Plastik,
        Logam, Kain, Karet_Kulit, Kaca, Lainnya
    ]

    colors = [
        '#FF6347', '#3CB371', '#ADD8E6', '#FFD700', '#B0C4DE',
        '#DA70D6', '#FF8C00', '#87CEEB', '#6A5ACD'
    ] 

    plt.figure(figsize=(10, 10))
    plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90,
            pctdistance=0.85, wedgeprops={'edgecolor': 'black'}) 

    
    center_circle = plt.Circle((0, 0), 0.70, fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(center_circle)

    plt.title('Komposisi Jenis Sampah 2024', fontsize=16)
    plt.axis('equal') 
    plt.show()

# --- Main Part of the Script ---
try:
    df = pd.read_csv('C:/EnergiHijau2025/Data_Komposisi_Jenis_Sampah.csv')

    plot_jenis(df)

except FileNotFoundError:
    print("Error: File 'C:/EnergiHijau2025/Data_Komposisi_Jenis_Sampah.csv' tidak ditemukan.")
except KeyError as e:
    print(f"Error: Kolom yang dibutuhkan tidak ditemukan di CSV. Pastikan nama kolom sudah benar. Missing column: {e}")
except Exception as e:
    print(f"Terjadi kesalahan: {e}")
